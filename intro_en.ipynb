# %% [markdown]
# #   Introduction. Basic methods of data analysis.

# %% [markdown]
# #   Libraries

# %%
import numpy as np
import matplotlib.pylab as plt
from matplotlib import gridspec
import pandas as pd
import scipy.stats as st
import seaborn as sns

# %% [markdown]
# #   Set the parameters ``matplotlib''''

# %%
#  A parameter to assign line thickness 
plt.rcParams['lines.linewidth'] = 1
#  Point width parameter 
plt.rcParams['lines.markersize'] = 6
#  parameter for the configuration of the x and y axles (number on the axles) 
plt.rcParams['xtick.labelsize'] = 24
plt.rcParams['ytick.labelsize'] = 24
#  Option for the font on the axles 
plt.rcParams['legend.fontsize'] = 24
#  This option is used to use the title option. 
plt.rcParams['axes.titlesize'] = 36
#  parameter for an x and y font task (name of axle) 
plt.rcParams['axes.labelsize'] = 12
plt.rcParams['figure.figsize'] = (8.0, 4.0)
#  Annotate or text option 
plt.rcParams['font.size'] = 10

# %% [markdown]
# #   Graphics

# %% [markdown]
# ##   Build One Graphics

# %%
def plot():
    plt.rcParams['lines.linewidth'] = 2
    plt.rcParams['lines.markersize'] = 6
    plt.rcParams['xtick.labelsize'] = 18
    plt.rcParams['ytick.labelsize'] = 18
    plt.rcParams['legend.fontsize'] = 18
    plt.rcParams['axes.titlesize'] = 36
    plt.rcParams['axes.labelsize'] = 18
    plt.rcParams['figure.figsize'] = (8.0, 4.0)
    plt.rcParams['font.size'] = 18
    ###########################################

    x = np.linspace(-np.pi, np.pi)
    y = np.sin(x)
    plt.plot(x, y, label='$y = sin(x)$')
    x = np.arange(-1, 2)
    y = x
    plt.plot(x, y, label='$y = x$')
#  Figure of the legend of the graph 
    plt.legend(loc='best')
#  signature of axles 
    plt.xlabel('$x$')
    plt.ylabel('$y$')
#  title 
    plt.title('Title')
#  Graphic grid diagram 
    plt.grid()
    plt.show()

# %%
plot()

# %% [markdown]
# ##   Several Graphics

# %%
def plot():
    plt.rcParams['lines.linewidth'] = 2
    plt.rcParams['lines.markersize'] = 6
    plt.rcParams['xtick.labelsize'] = 18
    plt.rcParams['ytick.labelsize'] = 18
    plt.rcParams['legend.fontsize'] = 18
    plt.rcParams['axes.titlesize'] = 36
    plt.rcParams['axes.labelsize'] = 18
    plt.rcParams['figure.figsize'] = (16.0, 8.0)
    plt.rcParams['font.size'] = 50
    ###########################################

    fig = plt.figure();

    gs = gridspec.GridSpec(2, 2)

    subs = []
    for sub in gs:
        subs.append(fig.add_subplot(sub))
    subs = np.reshape(subs, [2,2])

    subplotNames = ['First', 'Second', 'Third', 'Forth']

    for i in range(4):
        subs[i//2][i%2].annotate(text=subplotNames[i], xy=(0,0))
        subs[i//2][i%2].set_xlim(-1,1)
        subs[i//2][i%2].set_ylim(-1,1)

    plt.show()

# %%
plot()

# %% [markdown]
# #   Working with ``pandas'''

# %% [markdown]
#   ## Data uploading
#   Let's download csv file data using the pandas library.

# %%
data = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv')

# %%
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# ##   Some functions related to working with ``pandas''

# %% [markdown]
# ###   Sample the data from the sample

# %%
data.sample(n=2, random_state=42)
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 173  0.09178   0.0   4.05     0  0.510  6.416  84.1  2.6463    5  296
# 274  0.05644  40.0   6.41     1  0.447  6.758  32.9  4.0776    4  254
#
#      ptratio      b  lstat  medv
# 173     16.6  395.5   9.04  23.6
# 274     17.6  396.9   3.53  32.4

# %% [markdown]
# ###   Select the column we're interested in.

# %%
data['zn'].head(n=2)
# Out:
# 0    18.0
# 1     0.0
# Name: zn, dtype: float64

# %% [markdown]
# ###   Select several columns

# %%
data.iloc[:, 1:3].head(n=2)
# Out:
#      zn  indus
# 0  18.0   2.31
# 1   0.0   7.07

# %% [markdown]
# ###   Selecting the lines we're interested in

# %%
data.iloc[1:3]
# Out:
#       crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 1  0.02731  0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729  0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
#
#         b  lstat  medv
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7

# %% [markdown]
# ###   Subtract data from ``pandas'' to ``numpy'''' array

# %%
data2 = data.to_numpy()
data3 = data.values

# %%
(data3 - data2).sum()
# Out:
# 0.0

# %% [markdown]
# #   Visualization

# %% [markdown]
# ###   Description of sample matrix columns

# %%
data.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %% [markdown]
# ```
# CRIM: Per capita crime rate by town
# ZN: Proportion of residential land zoned for lots over 25,000 sq. ft
# INDUS: Proportion of non-retail business acres per town
# CHAS: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# NOX: Nitric oxide concentration (parts per 10 million)
# RM: Average number of rooms per dwelling
# AGE: Proportion of owner-occupied units built prior to 1940
# DIS: Weighted distances to five Boston employment centers
# RAD: Index of accessibility to radial highways
# TAX: Full-value property tax rate per $10,000
# PTRATIO: Pupil-teacher ratio by town
# B: 1000(Bk — 0.63)², where Bk is the proportion of [people of African American descent] by town
# LSTAT: Percentage of lower status of the population
# MEDV: Median value of owner-occupied homes in $1000s
# ```

# %% [markdown]
# ###   Pick a MEDV column.

# %%
x = data['medv'].values

# %% [markdown]
# ##   Histogram

# %%
plt.rcParams['figure.figsize'] = (8.0, 4.0)
###########################################

plt.hist(x)
plt.show()

# %% [markdown]
# ##   Nuclear assessment

# %%
plt.rcParams['figure.figsize'] = (8.0, 4.0)
###########################################

sns.kdeplot(x)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (8.0, 4.0)
###########################################

sns.distplot(x)
plt.show()
# Out:
# /tmp/ipykernel_36572/3529916535.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x)

# %% [markdown]
#   ## Correlation matrix
#   Let's show a correlation matrix for all features of the object.

# %%
plt.rcParams['figure.figsize'] = (8.0, 8.0)
###########################################

matrix = np.corrcoef(data.values, rowvar=False)
im = plt.matshow(matrix)
plt.colorbar(im)
plt.show()

# %% [markdown]
# ##   Similar graph in seaborn + pandas

# %%
plt.rcParams['figure.figsize'] = (8.0, 8.0)
plt.rcParams['font.size'] = 10
###########################################

cor = data.corr().round(2)
sns.heatmap(data=cor, annot=True)
plt.show()

# %% [markdown]
# ##   A pair of dissipation diagrams for the first three topics

# %%
sns.pairplot(data.iloc[:,0:3])
plt.show()

# %% [markdown]
# ##   Same graph in matplotlib

# %%
plt.rcParams['figure.figsize'] = (8.0, 8.0)
###########################################

def make_scatter(i, j, subplot):
    subplot.scatter(data.values[:, i], data.values[:, j])

def make_plot(i, j, subplot):
    if i == j:
#  Your code is here. 
    else:
#  Your code is here. 
    
for i in range(3):
    for j in range(3):
        subplot = plt.subplot(3, 3, i*3 + j + 1) # нумерация с единицы
        make_plot(i, j, subplot)

# %% [markdown]
# #   Sample estimates

# %% [markdown]
# ##   Average, median and dispersion

# %%
print('mean={}'.format(np.mean(x)))
print('std={}, std={}'.format(np.std(x), np.std(x, ddof=1)))
# Out:
# mean=22.532806324110677
# std=9.188011545278203, std=9.197104087379818

# %% [markdown]
# ##   Mode Distribution

# %%
print('median={}'.format(np.median(x)))
print('mode={}'.format(st.mode(x)))
# Out:
# median=21.2
# mode=ModeResult(mode=array([50.]), count=array([16]))
# /tmp/ipykernel_36572/639998581.py:2: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   print('mode={}'.format(st.mode(x)))

# %% [markdown]
# ##   Minimum and maximum sample value

# %%
print('maximum={}; ({})'.format(np.max(x), np.argmax(x)))
print('minimum={}; ({})'.format(np.min(x), np.argmin(x)))
# Out:
# maximum=50.0; (161)
# minimum=5.0; (398)

# %% [markdown]
# ##   Distribution Quantiles

# %%
alpha = 0.5
print('q(0.5)={}'.format(np.quantile(x, alpha)))
# Out:
# q(0.5)=21.2

# %% [markdown]
# ##   Interquartile scale

# %%
#  Your code is here.

# %% [markdown]
#   ``Expected response: ~7.975' ```'

# %% [markdown]
# ##   Rang x = $16

# %%
ind = np.where(x==16)[0]
print('rank(16)={}'.format(st.rankdata(x)[ind]))
# Out:
# rank(16)=[111.]

# %% [markdown]
# ##   Building cdf for a sub-sample containing only the values of US$>= $21.2

# %%
plt.rcParams['figure.figsize'] = (8.0, 4.0)
###########################################

plt.hist(x, cumulative=True, label='Full data')
plt.hist(x[x>=21.2], cumulative=True, label='$x>=21.2$')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ##   Sample estimates for sub-sampling only for $>= $21.2

# %%
#  Your code is here.

# %% [markdown]
# ```
#
# Expected response
# mean=29.001960784313727
# std=8.224008139636966, std=8.240181229279456
# median=25.0
# mode=ModeResult(mode=array([50.]), count=array([50.]))
# maximum=50.0; (67)
# minimum=21.2; (16)
# q(0.5)=25.0
# scale = 9.6000000000001
#
# ```
